# %%
options(jupyter.rich_display = F)
options(warnings = 0)

# %% [markdown]
# # A VERY SIMPLE ONE

# %% [markdown]
# ## QUESTION

# %% [markdown]
# Create a function named **"r1"** that takes an argument called "x".
#
# It has to return 2 times of this x.
#
# Try your function with x=3.
#
# ```r
# r1(3)
#
# [1] 6
# ```

# %% [markdown]
# ## SOLUTION

# %% [markdown]
# # BASIC FUNCTION

# %% [markdown]
# ## QUESTION

# %% [markdown]
# Include this as the first line:
# ```r
# RNGversion("3.3.1")
# ```
#
# Set seed to 123
#
# 1) Create a uniformly distributed vector of 40 length from 1 to 20 named **"uni_dis"**.
#
# 2) Create a sample vector of 40 length out of numbers from 1 to 20 named **"samp_vec"**
#
# 3) Create a function named **"difference"** that takes two arguments and shows the difference between the means of those arguments.
#
# 4) Show the difference between the means of **"samp_vec"** and **"uni_dis"** with using **"difference"** function as such:
#
# ```r
# difference(samp_vec, uni_dis)
#
# [1] -0.9615278
# ```

# %% [markdown]
# ## SOLUTION

# %% [markdown]
# # PLOT FUNCTION

# %% [markdown]
# ## QUESTION

# %% [markdown]
# 1) Write a function called **"plot_function"** that takes a vector that consists of names and ages in it,
#
# **Hint:** One input
#
# This function should first sort the input vector in a decreasing order.
#
# Then should plot the sorted vector.
#
# **Hint:** Returns only the plot
#
# Properties of the plot should be as follows;
#
# Name of the x axis should be "Frequency of Ages", name of the y axis should be "Ages"
#
# Name of the plot should be "MY PLOT", and colour should be red, also type should be line.
#
#
# 2) Now create a vector called **"names_ages"**, that consists following names and ages,
# Ahmet = 18, Ceren = 20, Efe = 22, Ece = 19, Kerem = 18, Asli = 20, Cansu = 23, Mehmet = 26
#
#
# 3) Try your function with the input of the function as the vector **"names_ages"** as such:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## SOLUTION

# %% [markdown]
# # VOLUME OF A SQUARE PYRAMID

# %% [markdown]
# ## QUESTION

# %% [markdown]
# Create a function to calculate volume of a square pyramid that takes two numbers:
#
# - An edge of the square (**x**)
# - An edge of the triangle which is isosceles (**y**)
#
# and returns the volume as such:
#
# ```r
# square_pyramid_volume(x = 5, y = 10)
#
# [1] 77.9512
# ```
#
#
# **Hint**
# - Given a is the edge of the base and h is the height volume is $\frac{1}{3}a^2h$
# - You should calculated the height of the pyramid

# %% [markdown]
# ## SOLUTION

# %% [markdown]
# # MAKING A CAKE

# %% [markdown]
# ## QUESTION

# %% [markdown]
# If you want to make a cake (one cake is for 1 guest), you need:
# - 4 eggs,
# - 1 cup of milk,
# - 2 cups of flour,
# - 1 cup of butter and
# - 0.1 cup of baking powder.
# - And at least 1 hour of cooking time.
#
# But you do not know how many guests you have today.
#
# So you need a **"cake_maker_calculater"** function.
#
# If you cannot learn how many guests you have and you have less than 1 hour for cooking before they come, you should start cooking.
#
# You can make the cake for four people.
#
# 1) Create a function for a cake with a single argument **guest**.
#
# 2) Define the default value of 4 for the number of guests.
#
# 3) Return the total quantity of all ingredients you use.
#
# 4) Calculate the ingredients for 6 guests as such:
#
# ```r
# cake_maker_calculater()
#
# [1] 32.4
#
# cake_maker_calculater(6)
#
# [1] 48.6
# ```
#
# Hint: you can use *sum()* function.

# %% [markdown]
# ## SOLUTION

# %% [markdown]
# # TELECOM FEES

# %% [markdown]
# ## QUESTION

# %% [markdown]
# You are working for a telecom company's pricing department.
#
# You are asked to bill consumers according to their call and internet expense.
#
# You charge consumers:
#
# - 3TL per hour of calls,
# - and 5TL per GB of internet usage.
# - Also, you apply a 20% discount for students.
#
# 1) Create function called **bill**, in order to calculate the bill. The function will take arguments of **calls**, **internet** and **category**.
#
#  - Calls and internet will represent hour of calls and internet usage respectively.
#  - Category will take values of either 1 or 2. 1 represents regular customers and 2 represents students (who will receive the discount).
#
# The function will by default assume that the customer is **not** a student.
#
# You will calculate the bill by finding the values **call_expense** and **internet_expense** within the function.
#
# Afterwards, the function should create a vector **final_expense** with two values, first one being the regular price and the second one being the discount price.
# Find them by adding the expenses and then applying the discount for the second value.
#
# In the end, return the appropriate value, based on the **category** argument.
#
#
# 2) Calculate the bill for a regular consumer, who talked for 4 hours and used 2 GB of internet. You should calculate:
#
# ```r
# bill(call = 4, internet = 2)
#
# [1] 22
# ```
#
#
# 3) Calculate the bill for a student, who talked for 2 hours and used 7 GB of internet. You should calculate:
#
# ```r
# bill(call = 2, internet = 7, category = 2)
#
# [1] 32.8
# ```

# %% [markdown]
# ## SOLUTION

# %% [markdown]
# # THE UNGRATEFUL FRIEND : LEVENT

# %% [markdown]
# ## QUESTION

# %% [markdown]
# Include this as the first line:
# ```r
# RNGversion("3.3.1")
# ```
#
#
# Set seed to 1847.
#
# Levent rates his friends on a scale of 0-10 based on his liking for them.
#
# 1) In a vector named **"points"** , store normally distributed 5 numbers with a mean of 6 and standard deviation of 3.
#
# 2) His friends are **"Ali"**, **"Ayse"**, **"Veli"**, **"Fatma"** and **"Taha"**, assign them to the numbers respectively.
#
# Levent is going to substract 3 points from each and stop being friends with the ones with negative points,
# and be BFFs with the one with the most points.
#
# 3) Write a function called **"friends"** which will do this calculation,
# and return the name and the point of the best friend side by side and then just the names of the ones he will stop being friends with as such:
#
# ```r
# friends(points)
#
# [1] "Ayse"             "7.20285351141669" "Ali"              "Taha"
# ```
#
#
# **Hint**: Make use of **names** and **unname** functions

# %% [markdown]
# ## SOLUTION

# %% [markdown]
# # WORK

# %% [markdown]
# ## QUESTION

# %% [markdown]
# Create a function called **"work"**.
#
# The function will take a vector of hours needed to complete different tasks.
#
# A person can do 10 hours of work in a day, and will be paid 300 TL per day.
#
# How much will they be paid to complete all tasks?
#
# (They will be paid 300 TL even if they work 1 hour on the last day, so don't forget to round up.)
#
# As such:
# ```r
# testvec <- c(13, 5, 21, 9, 10)
#
# work(testvec)
#
# [1] 1800
# ```
#
# **Hint:** You can use **ceiling** function for rounding up

# %% [markdown]
# ## SOLUTION

# %% [markdown]
# # WAGE AND AGE

# %% [markdown]
# ## QUESTION

# %% [markdown]
# A firm can employ **emp** number of random people from ages 18 to 65.
#
# It's possible that multiple people are of the same age.
#
# The default number of employees is 20.
#
# The minimum wage (what an 18 year old is paid) is 2558 tl.
#
# With one more year of experience, the person is paid 200 tl more. So, a 20 year old earns 2958 tl.
#
# Make a **"payroll"** function to calculate how much a firm will pay, for
# - a given number of employees = **emp** and
# - months = **mon**.
#
# The function will create a random vector of ages for the number of employees. Set seed to 1000 at the beginning (also with RNGversion 3.3.1) as such:
#
# ```r
# payroll(emp = 25, mon = 12)
#
#  [1]  66696 117096  42696 109896  88296  37896 114696  97896  54696  59496
# [11]  69096 117096  66696 129096 117096  37896  85896 102696  40296  97896
# [21]  47496 121896  61896  37896  93096
# ```
#
# **Hint:** Use **sample** function inside

# %% [markdown]
# ## SOLUTION

# %% [markdown]
# # RUN DENİZ RUN

# %% [markdown]
# ## QUESTION

# %% [markdown]
# Deniz goes running on a circular track with a radius of 30 meters everyday.
# He runs 4-15 times around it, he chooses it randomly and never runs the same times on the days of the same week.
# (You shouldn't use `replace = T` while creating random numbers.)
#
# 1) Sample seven numbers and assign these numbers to **"around"** .
#
# He wants to know the difference between the day he ran the most and the least in a week,
#
# 2) Write a function called **"difference"** that takes two arguments **"times"** and **"radius"** ( give **"radius"** argument its default value) that returns this difference as **kilometers**.
#
# Set RNG version to 3.3.1 and seed to 2000 for reproducibility as such:
#
# ```r
# around
#
# [1]  6 11  7 13 10 15  9
#
# difference(around)
# [1] 1.69646
# ```

# %% [markdown]
# ## SOLUTION

# %% [markdown]
# # HELP RICARDO

# %% [markdown]
# ## QUESTION

# %% [markdown]
# Ricardo took an accounting course at university, but the course was not interesting for him. Yet, he must remember what he learned in his new job.
#
# His task is to sell the product with 30% profit on the net value after calculating **one** year of depreciation according to the normal depreciation rate.
#
# According to this method, a fixed depreciation rate is applied to the asset to be depreciated or the amount of the asset is divided into economic life.
#
#
# 1) Create a function called **"help_ricardo"** which holds two inputs **"amount"** and **"economic_life"**.
#
# 2) Create a variable named **"depreciation"** calculating depreciation.
#
# 3) Calculate net value.
#
# 4) In order to see the sales price, create variable **"sales_price"** and return it as such:
#
# ```r
# help_ricardo(amount = 1000, economic_life = 5)
#
# [1] 1040
# ```
#
# **Hint:** amount / economic life = annual depreciation

# %% [markdown]
# ## SOLUTION

# %% [markdown]
# # WHICH ANIMAL DIES TODAY?

# %% [markdown]
# ## QUESTION

# %% [markdown]
# A psychopathic circus manager wants kill one animal who doesn't work hard enough each week.
#
# In order to select his victim, he randomly choses among 5 animals' names which earns him the least amount of money.
#
# The money he earns weekly from each animal is given below:
#
#
# |Animal|Profit|
# |:-|-:|
# |Elephant|800|
# |Swan|200|
# |Chimpanzee|1000|
# |Squirrel|550|
# |Lion|1600|
# |Panda|850|
# |Bear|230|
# |Otter|340|
# |Zebra|680|
# |Camel|410|
# |Crocodile|1200|
#
# Set RNGversion to 3.3.1 and seed to 1345
#
# 1) Create a vector named **"animal_names"** which contains the animals' names working in this circus and create another vector **"profit"** containing the circus mannager's profit out of each animal.
#
# 2) Create a function named **"bloody_circus"** which takes 2 arguments **"animals"** and **"money"**. This function should match **"animal_names"** argument to **"profit"** argument using names function.
#
# 3) This function should also select 5 animal which earns the least amount of money and choose 1 out of these animals randomly as the victim and return the name of victim along with its earning as such:
#
# ```r
# bloody_circus(animals = animal_names, money = profit)
#
# Camel
#   410
# ```

# %% [markdown]
# ## SOLUTION

# %% [markdown]
# # THE BUDGET LINE

# %% [markdown]
# ## QUESTION

# %% [markdown]
# Create a function named "**budget_line**" and that takes three arguments:
#
# - "**p1**"; price of the first good,
# - "**p2**"; price of the second good and
# - "**income**".
#
# The function should return the budget line of a consumer and the slope of the budget line at the same time.
#
# * Recall that the equation of a budget line is : **p1.x1 + p2.x2 = m(income)**
# * "**x1**" and "**x2**" correspond to the amount of the goods that the consumer spends money on.
# * The function should take "**x1**" from 0 to the maximum amount of "**x1**" that the consumer can buy.
# * An example :
#
# ```r
# budget_line(p1 = 75, p2=60, income = 8000)
# ```
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## SOLUTION

# %% [markdown]
# # DREAM TEAM

# %% [markdown]
# ## QUESTION

# %% [markdown]
# A physical education teacher wants to form a basketball team of 6 students for an upcoming school tournament.
#
# The teacher always prefers a taller player to a shorter one and according to the tournament rules each team must announce their players' average age
#
# Heights and ages of students who want to play in the tournament are as follows:
#
# |Name|Height|Age|
# |:-|:-|:-|
# |Boran|1.88|18|
# |Emre|2.03|15|
# |Cihan|1.85|18|
# |Melisa|1.77|18|
# |Berk|1.80|17|
# |Alp|1.97|16|
# |Selin|1.90|15|
# |Mustafa|1.70|16|
# |Nazlı|1.82|18|
#
# 1) Create 3 vectors:
# * a vector called **"names_1"** that contains the names of the students,
# * a vector called **"heights_1"** that contains heights of the students
# * and a vector called **"ages_1"** that contains ages of the students.
#
# 2) Create a function called **"dreamteam"** that takes 3 arguments **"name"** , **"height"** and **"age"**. This function should return a vector that contains names and age avarage of the players that teacher chooses as such:
#
# ``` r
# dreamteam(name = names_1, height = heights_1, age = ages_1)
#
# [1] "Mustafa" "Melisa"  "Berk"    "Cihan"   "Boran"   "Selin"
# [7] "17"
# ```

# %% [markdown]
# ## SOLUTION

# %% [markdown]
# # GPA CALCULATOR

# %% [markdown]
# ## QUESTION

# %% [markdown]
# 1) In Bogazici Management department, you have to take 19, 19, 20, 20, 17, 17, 15 and 15 credits each semester.
#
# Create a vector called **"AD"** which takes these credit values accordingly.
#
# 2) Create a spa vector named **"yourspa"** which takes the values 2.64, 3.30, 3.95, 2.47, 3.36, 2.92, 2.49, and 3.87 accordingly.
#
# 2) Create a function named **"gpa_calculator"** which takes 3 arguments: *credits, semester* and *spa*.
#
# Our function first needs to calculate GPA: Multiply corresponding SPA values with corresponding credits and then add them up. Then simply divide this value by the sum of credits taken so far.
#
# Then it should calculate what would your GPA be if you make 4.00 SPA next semester.
#
# The function should return the current SPA for the input semester and the scenario for the next semester as such:
#
# ```r
# gpa_calculator(credits = AD,
#                semester = 2,
#                spa = yourspa)
#
#  Current Scenario
# 2.961538 3.276786
# ```

# %% [markdown]
# ## SOLUTION

# %% [markdown]
# # UNEMPLOYEMENT RATE

# %% [markdown]
# ## QUESTION

# %% [markdown]
# In Poland, the economists found that there has been a consistent ratio between the unemployment rate of year *t-1* and year *t*.
#  The ratio is given as 0.76453.
#
#  1) Write a function taking unemployment rate of year t-1, the ratio and number of years after the previous year and returning unemployment rate of year t.
#
# You can use **prev_year** for the parameter name and **cur_year** for the year to be returned.
#  Name the function **poland_is_the_new_germany**.
#
#  The unemployment rate of 2011 was 14.7. Find the successive 5 years' unemployment rates.
#
# 2) Assign the outputs to a vector called **"migrate_to_poland"**.
#
# 3) Plot them using line plotting. Call the horizontal line **years** and the vertical line **unemployment rates**.
#
# Use **Migrate to Poland** as the title of plot as such:
#
# ```r
# migrate_to_poland <- poland_is_the_new_germany(14.7, years = 1:5)
# migrate_to_poland
#
# [1] 11.238591  8.592240  6.569025  5.022217  3.839635
# ```
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## SOLUTION

# %% [markdown]
# # TWO IN ONE

# %% [markdown]
# ## QUESTION

# %% [markdown]
# 1) Define a function called **"poster"** that takes 2 arguments, names as **n** and **k** with default k to be equal to 6.
#
# This function takes n and k, and gives k times n plus k.
#
# 2) Define another function called **"ripper"** that takes 2 arguments, names as **n** and **k** with default k to be equal to 6.
#
# This function takes n and k, and gives k times n minus k.
#
# 3) Define another function called **"multi"** that takes 2 arguments, names as **a** and **b** with default b to be equal to 6.
#
# This function has to give the result of 2 times the multiplication of the outcomes of poster and ripper functions with values a and b.
#
# Get the result of multi function with a equals 9 and no value given for b (which will use the dafault b = 6) and assign it to y as such:
#
# ```r
# y <- multi(9)
# y
#
# [1] 5760
# ```

# %% [markdown]
# ## SOLUTION
