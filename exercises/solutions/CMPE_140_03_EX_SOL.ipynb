# %%
options(jupyter.rich_display = F)

# %% [markdown]
# $\def\blue{\color{blue} {\bf {\text{blue}}}}
# \def\red{\color{red} {\bf {\text{red}}}}$

# %% [markdown]
# # G8 ECONOMIES

# %% [markdown]
# ## QUESTION

# %% [markdown]
# You wish to analyze the economies of member nations of the G8. To do this, you compare their gross domestic product per capita. The GDP per capita figures are given by the following (in US dollars):
#
# | Country | GDP per capita |
# |:--------|---------------|
# |France | 38476 |
# |Germany | 44469 |
# |Italy | 31952 |
# |UK | 39720 |
# |Japan | 38428 |
# |USA | 59531 |
# |Canada |45032 |
# |Russia | 10743 |
#
# 1) Assign the GDP values into a vector called **"g8"**, as such.
#
# ```r
# g8
#
#  France Germany   Italy      UK   Japan     USA  Canada  Russia
#   38476   44469   31952   39720   38428   59531   45032   10743
# ```
#
# 2) Create a histogram of these values as such:
#
# ![image.png](attachment:image.png)
#
# 3) For a simpler analysis, you are asked to create a histogram with only 3 bins (intervals) as such:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## SOLUTION

# %%
#1
g8 <- c("France" = 38476, "Germany" = 44469, "Italy" = 31952, "UK" = 39720, "Japan" = 38428,
        "USA" = 59531, "Canada" = 45032, "Russia" = 10743) #create the vector

#2
hist(g8) #1st histogram

#3
hist(g8,3) #lower the bin size to 3 by adjusting parameters

# %% [markdown]
# # APPLES AND BANANAS

# %% [markdown]
# ## QUESTION

# %% [markdown]
# 1) Create a vector called **"Apples"** including these numbers: 5, 3, 7, 4, 2 .
#
# 2) Create an another vector called **"Bananas"** including these numbers: 6, 2, 4, 3, 1
#
# 3) Plot **"Apples"** in $\red$ and specify the title as **"Apples And Bananas"** ,and specify the y label as **"Apples & Bananas"**.
#
# 4) Plot **"bicycles"** in $\blue$ on the same graph.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## SOLUTION

# %%
#1
Apples <- c(5,3,7,4,2)

#2 
Bananas <- c(6,2,4,3,1)

#3 
plot(Apples,col="red",main="Apples and Bananas", ylab = "Apples & Bananas")

#4
points(Bananas, col="blue")

# %% [markdown]
# # GRADE STATS

# %% [markdown]
# ## QUESTION

# %% [markdown]
# 1) Run the following code in RStudio
#
# ```r
# RNGversion("3.3.1")
# set.seed(1903)
# ```
#
# 2) Create a vector called **"grades"** that contains the normally distributed grades of 80 CMPE140 students with a mean of 55 and a standart deviation of 1.2
#
# 3) Create a vector called **"grade_stats"** which contains median, minimum, maximum and mean values of students' grades as such:
#
# ```r
# grade_stats
#
# median  minimum  maximum     mean
# 55.09072 52.50898 57.06178 54.99794
# ```
#
#
# **Hint:** You can use **range()** function to find the minimum and maximum values of the vector.

# %% [markdown]
# ## SOLUTION

# %%
#1
RNGversion("3.3.1")
set.seed(1903)

#2
grades <- rnorm(80 , mean = 55 , sd = 1.2 )

#3 
grade_stats <- c( median(grades) , range(grades) , mean(grades))
names(grade_stats) <- c("median", "minimum", "maximum" , "mean")

grade_stats

# %% [markdown]
# # EXCHANGE RATES

# %% [markdown]
# ## QUESTION

# %% [markdown]
# Here is the closing data of exchange rates of TL/USD in first 10 days of 2023:
#
# 0.198, 0.547, 0.988, 1.587, 2.223, 2.945, 3.741, 4.162, 4.879, 5.000.
#
# 1) Create a vector named **"currency"** with the rates.
#
# 2) Draw a line plot with the given data and paint the line red. Label the x-axis **"First Ten Days of 2023"**, y-axis as **"TL/USD"**.
#
# Also name the title as **"Future"** as such:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## SOLUTION

# %%
#1
currency <- c(0.198, 0.547, 0.988, 1.587, 2.223, 2.945, 3.741, 4.162, 4.879, 5.000)

#2
plot(currency, type = "l",
     main = "Future",
     col = "red",
     xlab = "First Ten Days of 2023",
     ylab = "TL/USD")

# %% [markdown]
# # CREATING A SAMPLE

# %% [markdown]
# ## QUESTION

# %% [markdown]
# You should first run this code:
#
# ```r
# RNGversion("3.3.1")
# set.seed(2019)
# ```
#
# 1) Create a vector named **"random"** which consist of 30 random integer between 1 and 100, without replacement (each number can only be used once).
#
# 2) Then sort these numbers in decreasing order and assign them to a new vector **"sorted"**.
#
# 3) Finally draw a line plot with the sorted vector and paint the line $\blue$.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## SOLUTION

# %%
RNGversion("3.3.1")
set.seed(2019)

#1
random <- sample(1:100, 30)

random

#2
sorted <- sort(random, decreasing = T)

sorted

#3
plot(sorted, type = "l", col = "blue")

# %% [markdown]
# # PLOTTING SERIALS

# %% [markdown]
# ## QUESTION

# %% [markdown]
# 1) Create a serial from 4 to 36 by 4 named **"seq1"**.
#
# 2) Create an another serial from 5 to 38 which has length of 9 named **"seq1"**.
#
# 3) Add these serials and assign **"seq3"**.
#
# 4) Plot **seq3** as a line. Assign the title **"Seq3"** and the y label **"Totals"**.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## SOLUTION

# %%
#1
seq1 <- seq(4,36,4)

#2
seq2 <- seq(5,38,length.out = 9)

#3
seq3 <- seq1+ seq2

#4
plot(seq3,type ="l",main = "Seq3",ylab = "Totals")

# %% [markdown]
# # IS IT RANDOM?

# %% [markdown]
# ## QUESTION

# %% [markdown]
# Please run the following code first for reproducability purposes:
#
# ```r
# RNGversion("3.3.1")
#
# set.seed(2112)
# ```
#
# 1) Create a vector **"random_1"** of 20 random numbers, distributed uniformly, between 0 and 100.
#
# 2) Create a vector **"random_2"** of 2000 random numbers, distributed uniformly, between 0 and 100.
#
# 3) Think about which vector will be more uniformly distributed. To test your hypothesis, create a histogram of both vectors separately. This first histogram should be as such:
#
# ![image.png](attachment:image.png)
#
#
# Which one was more uniform? Why?

# %% [markdown]
# ## SOLUTION

# %%
RNGversion("3.3.1")
set.seed(2112)

#1
random_1 <- runif(20,0,100) #vector with 20 numbers

#2
random_2 <- runif(2000,0,100) #vector with 2000 numbers

#3
hist(random_1)
hist(random_2)

#After creating the histograms, you will see that the second vector is distributed more uniformly than the first.
#This is due to the fact that a larger sample size of numbers are selected in the second vector.

# %% [markdown]
# # EXAM RESULTS

# %% [markdown]
# ## QUESTION

# %% [markdown]
# Cenk's results from 5 exams and the clasroom average of those exams are as follows:
#
# |Exam|Average|Cenk's result|
# |--|-:|-:|
# |1|88|86|
# |2|85|84|
# |3|73|79|
# |4|77|74|
# |5|78|73|
#
# <!--
# * 1st Exam > Average = 88 Cenk's result = 86
# * 2nd Exam > Average = 85 Cenk's result = 84
# * 3rd Exam > Average = 73 Cenk's result = 79
# * 4th Exam > Average = 77 Cenk's result = 74
# * 5th Exam > Average = 78 Cenk's result = 73
# -->
#
# Create two vectors "**Cenk**" and "**average**" holding the data. Create a plot which shows whether Cenk's results are higher or lower than the clasroom average (plotted as $\red$ circles) which looks like as follows:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## SOLUTION

# %%
#Create the vectors
average <- c(88,85,73,77,78)
Cenk <- c(86,84,79,74,73)

#Create the plot
plot(average, col="red",xlab="Exams",ylab="Points")
points(Cenk)
title("Cenk's Results vs. Average")

# %% [markdown]
# # SELECTING TEACHING ASSISTANT

# %% [markdown]
# ## QUESTION

# %% [markdown]
# CMPE teacher wants to select an assistant and decides to pick 4 students randomly and then choose the student with highest score as his assistant. Find which student will be selected.
#
#
# 1) First run:
#
# ```r
# RNGversion("3.3.1")
# set.seed(2019)
# ```
#
#  2) Create vector named **"ppl"** and **"grades"** which contains students' names and grades as follows:
#
# |Name|Grade|
# |:-|-:|
# |Guzide|68|
# |Gulsun|72|
# |Gulin|95|
# |Gulbin|26|
# |Gurgen|52|
# |Gollum|98|
# |Gul|12|
# |Gulse|36|
# |Gulay|86|
#
# 3) Choose 4 students randomly to create vector **"random_ppl"**.
#
# 4) Select the student with highest score from **"random_ppl"** and assign him/her to vector **"selected"** as such:
#
# ```r
# Gollum
#     98
# ```

# %% [markdown]
# ## SOLUTION

# %%
#1 set seed
RNGversion("3.3.1")
set.seed(2019)

#2 create "ppl" and "grades". then assign "grades" to "ppl" using names() function
ppl <- c("Guzide", "Gulsun", "Gulin", "Gulbin", "Gurgen", "Gollum", "Gul", "Gulse", "Gulay")
grades <- c(68, 72, 95, 26, 52, 98, 12, 36, 86)
names(grades) <- ppl

#3 randomly select 4 people using sample() function and assign it to "random_ppl"
random_ppl <- sample(grades,4)

#4 pick the first one of sorted "random_ppl" vector and assign it to "selected"
selected <- sort(random_ppl, decreasing = T)[1]

#5 checking selected student
selected

# %% [markdown]
# # NET INCOME OVER TIME

# %% [markdown]
# ## QUESTION

# %% [markdown]
# 1) The wages of the employees of a company are as follows:
#
# |Title|Wage|
# |:-|-:|
# |ceo|50000|
# |cfo|40000|
# |cmo|35000|
# |accountant|10000|
# |intern|5000|
#
# Store these data in a vector called **'wages'**.
#
# 2) There is a raise in wages by 5%, update accordingly.
#
# 3) The income tax is 10% for those whose wage exceeds 30000$ and 1\% for others. Calculate the net income for each employee and store them in **'nincome'**.
#
# 4) Their employment time in years are respectively 20, 15, 17, 5 and 1 years. Store the data in **'time'**.
#
# 5) Plot the net income and employment time with time being the x-axis. Name the plot *'NI x time'*, x-axis *'time in the company'*, y-axis *'Net Income'* as such:
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## SOLUTION

# %%
#1
wages <- c(ceo = 50000, cfo = 40000, cmo = 35000, accountant = 10000, intern = 5000)

#2
wages <- wages * (1.05)

#3
wages[wages > 30000] <- wages[wages > 30000] * 0.90
wages[wages < 30000] <- wages[wages < 30000] * 0.99

#4
time <- c(20, 15, 17, 5, 1)
names(time) <- names(wages)

#5
plot(time, wages, main = 'NI x time', xlab = 'time in the company', ylab = 'Net Income')

# %% [markdown]
# # BAKER

# %% [markdown]
# ## QUESTION

# %% [markdown]
# A baker sells fresh bread every day of the week.
# Starting on Monday, he sells 83, 77, 85, 81, 79, 112, 121 loaves.
#
# 1) Make a **"bread"** vector with the number of loaves of bread the baker sells.
#
# 2) Four weeks pass. Each week, he sells 5 more bread on each day. So, on Mondays he sold 83, 88, 93, 98 bread.
#
# Make a **"bread_month"** vector that shows how much bread he sold every day for 28 days.
#
# Also make a **"days"** vector with the same length as bread_month.
#
# 3) Plot the days on the x-axis and month of bread on the y-axis. Make the marker $\red$.
#
# Name the x-axis **"Days"**, y-axis **"Bread sold"**, title **"A month of bread"** as such:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## SOLUTION

# %%
#1
bread <- c(83, 77, 85, 81, 79, 112, 121)

#2 
bread_month <- c(bread, bread + 5, bread + 10, bread + 15)
days <- seq(length(bread_month))
days

#3
plot(days, bread_month, xlab = "Days", ylab = "Bread sold", main = "A month of bread", col = "red")

# %% [markdown]
# # A POSTMAN

# %% [markdown]
# ## QUESTION

# %% [markdown]
#  Copy the code below to R Studio
# ```r
# RNGversion("3.3.1")
# set.seed(3)
# distance <- sample(1:10, 15, replace=TRUE)
# ```
#
# In a street, blocks are positioned next to each other. A postman has some letters that he has to distribute at this street. He  rides his bicycle starting from the fifth block. The distance vector shows how many blocks  this  postman passes by to distribute the letters .For example he rides his bicyle for 2 blocks to give the first letter.
#
# 1)	Create a vector  "**position**"  whose elements correspond to this postman’s positions.(first element = first position)
#
# 2)	Show this postman’s positions and the distance passed by him on the same plot. The plot should answer these questions:
#  * At which block he is at that spesific position ?
#  * How many blocks he passed by to arrive at that position from the previous position ?
#   (For example ,at fifth position, he is at 24th block and he rode his bicycle for 4 blocks from the forth position to arrive at fifth position)
#
# It should look like as follows:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## SOLUTION

# %%
#1
RNGversion("3.3.1")
set.seed(3)
distance <- sample(1:10,15,replace=TRUE)
position <- cumsum(c(5,distance)) # Create the position vector using cumsum function 
position

#2
distance <- c(0,distance) #Upgrade the distance function
distance
plot(position,col="blue", type="l",xlab="position_number", ylab="block/distance") #Create the plot
points(distance,col="red")

# %% [markdown]
# # PLOTTING THE WEATHER

# %% [markdown]
# ## QUESTION

# %% [markdown]
# We want to compare the temperatures observed in a city during 2 months.
#
# 1) Run this code:
# ```r
# RNGversion("3.3.1")
# set.seed(1998)
# ```
#
# 2) Create a vector **"temps"** and to represent temperature values measured in a city during a year. These temperatures should be random numbers normally distributed. (Take a year as 365 days)
#
# 3) Create vectors **"month1"** and **"month2"** to represent first and second months' temperature values of this year. (Take a month as 30 days)
#
#
# 4) Plot the the temperatures of these 2 months during 30 days. The title should be **"Weather In 2 Countries"**, x axis should be labeled as **"Days"** and y axis should be labeled as **"Temperatures"**. Use $\red$ color for the first month and $\blue$ for the second.
#
# The plot will look like this:
#
# ![Rplot02.png](attachment:Rplot02.png)
#
#
# **Hint:** You should use rnorm() function

# %% [markdown]
# ## SOLUTION

# %%
#1
set.seed(1998)

#2 create the vector "temp" by using rnorm function
temp <- rnorm(365,16,7)

#3 create "mounth1" by selecting first 30 values in "temp" and create "mounth2" by selecting values between 30th and 60th in "temp" vector. We use [] for selecting.
mounth1 <- temp[seq(1,30)]
mounth2 <- temp[seq(31,60)]

#4 plot the graph
plot( seq(1,30, by=1), mounth1, type = "l", col="red", main = "Weather In 2 Countries", xlab = "Days", ylab = "Temperatures")
lines(seq(1,30, by=1), mounth2, col="blue")

# %% [markdown]
# # GDP GROWTH OF TURKEY

# %% [markdown]
# ## QUESTION

# %% [markdown]
# 1) GDP of Turkey in 2008 is 764336 Billion Dollars. Create a variable named **"gdp_2008"** and assing the value 764336 to it
#
# 2) GDP growth rates of Turkey from 2009 to 2018 are as follows: -4.7 , 8.5 , 11.1 , 4.8 , 8.5 , 5.2 , 6.1 , 3.2 , 7.4 , 2.6 . Create a vector called **"growth_rates"** that contains these values.
#
# 3) Create a vector named **"all_gdp"** that contains GDP values of Turkey from 2008 to 2018
#
# 4) Create a plot with years on x-axis and GDP values on y-axis, name x-axis as "Years" and y-axis as "GDP"
#
#
# Hint: You can use *cumsum()* function to calculate GDP values simultaneously.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## SOLUTION

# %%
#1
gdp_2008 <- 764336 

#2
growth_rates <- c(-4.7 , 8.5 , 11.1 , 4.8 , 8.5 , 5.2 , 6.1 , 3.2 , 7.4 , 2.6)

#3
all_gdp <-  gdp_2008 * c(1 , cumprod(( growth_rates + 100)/100))

#4
years <- c(2008 : 2018)
plot( years , all_gdp , type="l", xlab = "Years" , ylab = "GDP")
