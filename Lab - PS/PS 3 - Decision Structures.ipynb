# %% [markdown]
# # Decision Structures
#
# 21.02.2018, prepared by Merve Betül Gökçe
#
# ---
#
# ## Exercise 1
#
# Create an R script that prints the absolute value of an integer vector x of length one.

# %%
x <- -10
# Or, getting data from user with readline
# x <- as.numeric(readline("Enter an integer: "))
abs <- x
if (x < 0) {
  abs = -x
}
cat("The absolute value of ", x, " is ", abs , "\n" )
# Out:
# The absolute value of  -10  is  10

# %% [markdown]
# ## Exercise 2
#
# Create an R script that calculates the square root of a given integer vector x of length one,
# if the value contained in x is negative it should return NA.

# %%
x <- as.numeric(readline("Enter an integer: "))
if (x >= 0) {
  cat("The square root is", sqrt(x))
} else cat("The square root is", NA)
# Out:
# Enter an integer: 4
# The square root is 2

# %% [markdown]
# Even writing _else_ without curly brackets is correct
# **IF THERE IS ONLY ONE STATEMENT** as shown above
#
# It is better to use them always. Reduces the mistakes and improves readability!

# %%
if (x >= 0) {
  cat("The square root is", sqrt(x))
} else {
  cat("The square root is", NA)
}
# Out:
# The square root is 2

# %% [markdown]
# ## Exercise 3
#
# Create an R script that prints the maximum value out of the elements of a numeric vector x of length 2.

# %%
x <- c(2, 3)
if(x[1] >= x[2]) {
  print(x[1])
  # or, cat("Max value is", x[1], "\n")
  # use ?cat for further information
} else {
  print(x[2])
}
# Out:
# [1] 3

# %% [markdown]
# ## Exercise 4
#
# Create an R script that prints _TRUE_ if the elements of a vector x, with length 3, are strictly increasing.

# %%
x <- c(1, 4, 3)

if(x[1] < x[2] && x[2] < x[3]) print(TRUE) else print(FALSE)
# Out:
# [1] FALSE

# %% [markdown]
# Again both if and else only has **ONE STATEMENT** so code above is correct
# BUT it is better to write them like below

# %%
if(x[1] < x[2] && x[2] < x[3]) {
  print(TRUE)
} else {
  print(FALSE)
}
# Out:
# [1] FALSE

# %% [markdown]
# ## Exercise 5
#
# Create an R script that prints the max value of a vector x with length 3.

# %%
x <- c(5, 6, 8)

if(x[2] < x[1] && x[3] < x[1]) {
  print(x[1]) 
} else if(x[3] < x[2] && x[1] < x[2]) {
  print(x[2]) 
} else {
  print(x[3])
}
# Out:
# [1] 8

# %% [markdown]
# ## Exercise 6
# Create an R script that, given a numeric vector x with length 3, will print the elements by order from high to low.

# %%
x <- c(30, 120, 100)

if (x[1] > x[2]){
  fir <- x[1]
  sec <- x[2]
} else {
  fir <- x[2]
  sec <- x[1]
}
if (x[3] > fir & x[3] > sec) {
  thi <- sec
  sec <- fir
  fir <- x[3]
} else if (x[3] < fir & x[3] < sec) {
  thi <- x[3]
} else {
  thi <- sec
  sec <- x[3]
}
cat (fir, sec, thi, "\n")
# Out:
# 120 100 30

# %% [markdown]
# ## Extra Question 1
#
# Determine whether a given year is a leap year or NOT using nested if and logical operators.

# %%
x <- as.numeric(readline(prompt = "Enter the year: "))

if (x %% 4 != 0) {
  print("it is a common year")
} else if (x %% 100 != 0) {
  print("it is a leap year")
} else if (x %% 400 != 0) {
  print("it is a common year")
} else {
  print("it is a leap year")
}
# Out:
# Enter the year: 2018
# [1] "it is a common year"

# %% [markdown]
# ## Extra Question 2
#
# Find all the leap years between 1600-2400 using ifelse() and seq. (filtering can be needed)

# %%
years <- seq(1600, 2400, 1)
ifelse(years %% 4 == 0, years, 0)
# Out:
#   [1] 1600    0    0    0 1604    0    0    0 1608    0    0    0 1612    0    0
#  [16]    0 1616    0    0    0 1620    0    0    0 1624    0    0    0 1628    0
#  [31]    0    0 1632    0    0    0 1636    0    0    0 1640    0    0    0 1644
#  [46]    0    0    0 1648    0    0    0 1652    0    0    0 1656    0    0    0
#  [61] 1660    0    0    0 1664    0    0    0 1668    0    0    0 1672    0    0
#  [76]    0 1676    0    0    0 1680    0    0    0 1684    0    0    0 1688    0
#  [91]    0    0 1692    0    0    0 1696    0    0    0 1700    0    0    0 1704
# [106]    0    0    0 1708    0    0    0 1712    0    0    0 1716    0    0    0
# [121] 1720    0    0    0 1724    0    0    0 1728    0    0    0 1732    0    0
# [136]    0 1736    0    0    0 1740    0    0    0 1744    0    0    0 1748    0
# [151]    0    0 1752    0    0    0 1756    0    0    0 1760    0    0    0 1764
# [166]    0    0    0 1768    0    0    0 1772    0    0    0 1776    0    0    0
# [181] 1780    0    0    0 1784    0    0    0 1788    0    0    0 1792    0    0
# [196]    0 1796    0    0    0 1800    0    0    0 1804    0    0    0 1808    0
# [211]    0    0 1812    0    0    0 1816    0    0    0 1820    0    0    0 1824
# [226]    0    0    0 1828    0    0    0 1832    0    0    0 1836    0    0    0
# [241] 1840    0    0    0 1844    0    0    0 1848    0    0    0 1852    0    0
# [256]    0 1856    0    0    0 1860    0    0    0 1864    0    0    0 1868    0
# [271]    0    0 1872    0    0    0 1876    0    0    0 1880    0    0    0 1884
# [286]    0    0    0 1888    0    0    0 1892    0    0    0 1896    0    0    0
# [301] 1900    0    0    0 1904    0    0    0 1908    0    0    0 1912    0    0
# [316]    0 1916    0    0    0 1920    0    0    0 1924    0    0    0 1928    0
# [331]    0    0 1932    0    0    0 1936    0    0    0 1940    0    0    0 1944
# [346]    0    0    0 1948    0    0    0 1952    0    0    0 1956    0    0    0
# [361] 1960    0    0    0 1964    0    0    0 1968    0    0    0 1972    0    0
# [376]    0 1976    0    0    0 1980    0    0    0 1984    0    0    0 1988    0
# [391]    0    0 1992    0    0    0 1996    0    0    0 2000    0    0    0 2004
# [406]    0    0    0 2008    0    0    0 2012    0    0    0 2016    0    0    0
# [421] 2020    0    0    0 2024    0    0    0 2028    0    0    0 2032    0    0
# [436]    0 2036    0    0    0 2040    0    0    0 2044    0    0    0 2048    0
# [451]    0    0 2052    0    0    0 2056    0    0    0 2060    0    0    0 2064
# [466]    0    0    0 2068    0    0    0 2072    0    0    0 2076    0    0    0
# [481] 2080    0    0    0 2084    0    0    0 2088    0    0    0 2092    0    0
# [496]    0 2096    0    0    0 2100    0    0    0 2104    0    0    0 2108    0
# [511]    0    0 2112    0    0    0 2116    0    0    0 2120    0    0    0 2124
# [526]    0    0    0 2128    0    0    0 2132    0    0    0 2136    0    0    0
# [541] 2140    0    0    0 2144    0    0    0 2148    0    0    0 2152    0    0
# [556]    0 2156    0    0    0 2160    0    0    0 2164    0    0    0 2168    0
# [571]    0    0 2172    0    0    0 2176    0    0    0 2180    0    0    0 2184
# [586]    0    0    0 2188    0    0    0 2192    0    0    0 2196    0    0    0
# [601] 2200    0    0    0 2204    0    0    0 2208    0    0    0 2212    0    0
# [616]    0 2216    0    0    0 2220    0    0    0 2224    0    0    0 2228    0
# [631]    0    0 2232    0    0    0 2236    0    0    0 2240    0    0    0 2244
# [646]    0    0    0 2248    0    0    0 2252    0    0    0 2256    0    0    0
# [661] 2260    0    0    0 2264    0    0    0 2268    0    0    0 2272    0    0
# [676]    0 2276    0    0    0 2280    0    0    0 2284    0    0    0 2288    0
# [691]    0    0 2292    0    0    0 2296    0    0    0 2300    0    0    0 2304
# [706]    0    0    0 2308    0    0    0 2312    0    0    0 2316    0    0    0
# [721] 2320    0    0    0 2324    0    0    0 2328    0    0    0 2332    0    0
# [736]    0 2336    0    0    0 2340    0    0    0 2344    0    0    0 2348    0
# [751]    0    0 2352    0    0    0 2356    0    0    0 2360    0    0    0 2364
# [766]    0    0    0 2368    0    0    0 2372    0    0    0 2376    0    0    0
# [781] 2380    0    0    0 2384    0    0    0 2388    0    0    0 2392    0    0
# [796]    0 2396    0    0    0 2400

# %% [markdown]
# ## Extra Question 3
#
# Draw a decision tree and write the code for the problem below using nested if-else:
#  - If grade is less than 60, the student will "fail".
#  - If grade is above 60, then the student will "pass" and the corresponding "letter grade" will be asigned.

# %%
grade <- 82
if(grade < 60) {
  print("fail")
} else {
  print("pass")
  if(grade < 65) {
    print("DD")
  } else if(grade < 70) {
    print("DC")
  } else if(grade < 75) {
    print("CC")
  } else if (grade < 80) {
    print("CB")
  } else if(grade < 85) {
    print("BB")
  } else if(grade < 90) {
    print("BA")
  } else {
    print("AA")
  }
}
# Out:
# [1] "pass"
# [1] "BB"
